# %%
import pandas as pd
from pathlib import Path
import pickle
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import MaxAbsScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score

# %%
work_path = Path('.')

# %%
df = pd.read_csv(work_path.joinpath('full_data.csv').__str__())

# %%
target_class_map = {target: n for n, target in enumerate(df.topic.unique())}

# %%
target_class_map
# Out:
# {'Наука и техника': 0,
#  'Экономика': 1,
#  'Силовые структуры': 2,
#  'Туризм/Путешествия': 3,
#  'Общество/Россия': 4,
#  'Спорт': 5,
#  'Бывший СССР': 6}

# %%
df.topic = df.topic.map(target_class_map)

# %%
test_idx = []
for target in df.topic.unique():
    test_idx += df[df.topic == target].sample(frac=0.25, random_state=42).index.tolist()

# %%
train_df = df.drop(index=test_idx)
test_df = df.loc[test_idx]

# %%
test_df.groupby('topic').agg({'url': 'count'}) / len(test_df)
# Out:
#             url
# topic
# 0      0.094008
# 1      0.323519
# 2      0.191632
# 3      0.123795
# 4      0.235882
# 5      0.004477
# 6      0.026687

# %%
train_df.groupby('topic').agg({'url': 'count'}) / len(train_df)
# Out:
#             url
# topic
# 0      0.094049
# 1      0.323521
# 2      0.191542
# 3      0.123716
# 4      0.235898
# 5      0.004533
# 6      0.026740

# %% [markdown]
# # base_line

# %%
X_train = train_df.content.to_numpy()
y_train = train_df.topic.to_numpy()

X_test = test_df.content.to_numpy()
y_test = test_df.topic.to_numpy()

# %%
vec = CountVectorizer() # подбор гиперпараметров очень помогает
vec.fit(X_train)

bow = vec.transform(X_train)  # bow — bag of words (мешок слов)
bow_test = vec.transform(X_test)

# %%
scaler = MaxAbsScaler()
bow = scaler.fit_transform(bow)
bow_test = scaler.transform(bow_test)

# %%
clf = LogisticRegression(max_iter=200, random_state=42)
clf.fit(bow, y_train)
pred = clf.predict(bow_test)

# %%
f1_score(y_test, pred, average='weighted')
# Out:
# np.float64(0.9106877884200845)

# %%
with open(work_path.joinpath('models/base_line_log_reg_model.pickle').__str__(),'wb') as f:
    pickle.dump(clf, f)

# %% [markdown]
# # params search

# %% [markdown]
# ## stop_words and lemmatize

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from pymystem3 import Mystem
from string import punctuation
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
mystem = Mystem() 
russian_stopwords = stopwords.words("russian")

# %%
def preprocess_text(text):
    tokens = mystem.lemmatize(text.lower())
    tokens = [token for token in tokens if token not in russian_stopwords\
              and token != " " \
              and token.strip() not in punctuation]
    
    text = " ".join(tokens)
    
    return text

# %%
X_train = train_df.content.apply(preprocess_text).to_numpy()
y_train = train_df.topic.to_numpy()

X_test = test_df.content.apply(preprocess_text).to_numpy()
y_test = test_df.topic.to_numpy()

# %%
vec = CountVectorizer() 
vec.fit(X_train)

bow = vec.transform(X_train)
bow_test = vec.transform(X_test)

# %%
scaler = MaxAbsScaler()
bow = scaler.fit_transform(bow)
bow_test = scaler.transform(bow_test)

# %%
clf = LogisticRegression(max_iter=200, random_state=42)
clf.fit(bow, y_train)
pred = clf.predict(bow_test)

# %%
f1_score(y_test, pred, average='weighted')
# Out:
# np.float64(0.9139257939919727)

# %% [markdown]
# **Вывод**
# Лемматизация и удалиение стоп слов улучшает score

# %% [markdown]
# ### LogisticRegression params

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {
    'penalty': ['l2'],
    'class_weight': [None, 'balanced'],
    'max_iter': [100, 200, 300]
}

# %%
clf = LogisticRegression(random_state=42)

# %%
gscv = GridSearchCV(clf, parameters)

# %%
gscv.fit(bow, y_train)
# Out:
# GridSearchCV(estimator=LogisticRegression(random_state=42),
#              param_grid={'class_weight': [None, 'balanced'],
#                          'max_iter': [100, 200, 300], 'penalty': ['l2']})

# %%
pd.DataFrame(gscv.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      23.846641      2.372425         0.059079        0.043597
# 1      23.421624      2.450737         0.040975        0.043890
# 2      23.576924      2.048472         0.023129        0.035481
# 3      21.421451      1.647350         0.076616        0.034822
# 4      21.404652      1.299862         0.075054        0.034515
# 5      22.339177      1.277196         0.040398        0.043767
#
#   param_class_weight  param_max_iter param_penalty  \
# 0               None             100            l2
# 1               None             200            l2
# 2               None             300            l2
# 3           balanced             100            l2
# 4           balanced             200            l2
# 5           balanced             300            l2
#
#                                               params  split0_test_score  \
# 0  {'class_weight': None, 'max_iter': 100, 'penal...           0.918818
# 1  {'class_weight': None, 'max_iter': 200, 'penal...           0.918818
# 2  {'class_weight': None, 'max_iter': 300, 'penal...           0.918818
# 3  {'class_weight': 'balanced', 'max_iter': 100, ...           0.925416
# 4  {'class_weight': 'balanced', 'max_iter': 200, ...           0.925416
# 5  {'class_weight': 'balanced', 'max_iter': 300, ...           0.925416
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.919105           0.915925           0.901578           0.771306
# 1           0.919105           0.915925           0.901578           0.771306
# 2           0.919105           0.915925           0.901578           0.771306
# 3           0.926277           0.918795           0.906456           0.754663
# 4           0.926277           0.918795           0.906456           0.754663
# 5           0.926277           0.918795           0.906456           0.754663
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.885346        0.057383                4
# 1         0.885346        0.057383                4
# 2         0.885346        0.057383                4
# 3         0.886321        0.066210                1
# 4         0.886321        0.066210                1
# 5         0.886321        0.066210                1

# %%
pred = gscv.best_estimator_.predict(bow_test)

# %%
f1_score(y_test, pred, average='weighted')
# Out:
# np.float64(0.9199695387639771)
