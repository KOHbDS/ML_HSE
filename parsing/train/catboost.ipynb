# %%
from catboost import CatBoostClassifier, Pool
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from pathlib import Path
import pandas as pd
from sklearn.metrics import f1_score

# %%
work_path = Path('.')
df = pd.read_csv(work_path.joinpath('full_data.csv').__str__())
target_class_map = {target: n for n, target in enumerate(df.topic.unique())}
df.topic = df.topic.map(target_class_map)

test_idx = []
for target in df.topic.unique():
    test_idx += df[df.topic == target].sample(frac=0.25, random_state=42).index.tolist()

# %%
train_df = df.drop(index=test_idx)
test_df = df.loc[test_idx]

# %% [markdown]
# # CatBoostClassifier on text_feature

# %%
train_set = Pool(data=train_df[['content']],
                  label=train_df.topic.to_numpy(),
                  text_features=['content'])

eval_set = Pool(data=test_df[['content']],
                  label=test_df.topic.to_numpy(),
                  text_features=['content'])

# %%
param_grid = {
    'iterations': [100, 200],
    'learning_rate': [0.01, 0.1],
    'depth': [3, 6, 9],
    'auto_class_weights': ['Balanced', 'SqrtBalanced']
}

scorer = make_scorer(f1_score, average='weighted')

# %%
base_params = {
    'random_state': 42,
    "verbose": False,
    'early_stopping_rounds': 5,
    #'use_best_model': True,
    "loss_function": "MultiClass",
    'text_features': ['content']
}
model = CatBoostClassifier(**base_params)

# %%
clf = GridSearchCV(model, param_grid)

# %%
clf.fit(train_df[['content']], train_df.topic.to_numpy())
# Out:
# GridSearchCV(estimator=<catboost.core.CatBoostClassifier object at 0x7f3f8affbd00>,
#              param_grid={'auto_class_weights': ['Balanced', 'SqrtBalanced'],
#                          'depth': [3, 6, 9], 'iterations': [100, 200],
#                          'learning_rate': [0.01, 0.1]})

# %%
pd.DataFrame(clf.cv_results_)#.dropna(subset=['split0_test_score'])
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        4.260560      0.016294         0.067887        0.008800
# 1        4.086935      0.012434         0.060750        0.002067
# 2        7.077548      0.075237         0.051560        0.004011
# 3        6.782198      0.022347         0.052281        0.002161
# 4       20.061338      0.209043         0.062620        0.004044
# 5       19.543366      0.071017         0.062310        0.001218
# 6       37.947120      1.216650         0.057299        0.002405
# 7       36.386769      0.576203         0.055955        0.003241
# 8       67.473048      0.355515         0.066420        0.003530
# 9       67.459434      0.244417         0.067873        0.002905
# 10     132.860110      0.521823         0.057407        0.002609
# 11     134.243133      0.630226         0.059018        0.003448
# 12       4.160860      0.052337         0.060201        0.003149
# 13       4.005573      0.014354         0.060139        0.003219
# 14       7.036293      0.052562         0.051592        0.004000
# 15       6.750186      0.033872         0.051864        0.000818
# 16      19.923841      0.075124         0.061446        0.001929
# 17      19.168460      0.139269         0.063077        0.004285
# 18      38.151408      0.197141         0.055070        0.004074
# 19      37.026098      0.236505         0.053200        0.003990
# 20      67.369317      0.196908         0.066101        0.002642
# 21      67.195205      0.413772         0.067728        0.003120
# 22     133.399270      0.452256         0.062914        0.005472
# 23     133.812508      0.370196         0.062542        0.006288
#
#    param_auto_class_weights  param_depth  param_iterations  \
# 0                  Balanced            3               100
# 1                  Balanced            3               100
# 2                  Balanced            3               200
# 3                  Balanced            3               200
# 4                  Balanced            6               100
# 5                  Balanced            6               100
# 6                  Balanced            6               200
# 7                  Balanced            6               200
# 8                  Balanced            9               100
# 9                  Balanced            9               100
# 10                 Balanced            9               200
# 11                 Balanced            9               200
# 12             SqrtBalanced            3               100
# 13             SqrtBalanced            3               100
# 14             SqrtBalanced            3               200
# 15             SqrtBalanced            3               200
# 16             SqrtBalanced            6               100
# 17             SqrtBalanced            6               100
# 18             SqrtBalanced            6               200
# 19             SqrtBalanced            6               200
# 20             SqrtBalanced            9               100
# 21             SqrtBalanced            9               100
# 22             SqrtBalanced            9               200
# 23             SqrtBalanced            9               200
#
#     param_learning_rate                                             params  \
# 0                  0.01  {'auto_class_weights': 'Balanced', 'depth': 3,...
# 1                  0.10  {'auto_class_weights': 'Balanced', 'depth': 3,...
# 2                  0.01  {'auto_class_weights': 'Balanced', 'depth': 3,...
# 3                  0.10  {'auto_class_weights': 'Balanced', 'depth': 3,...
# 4                  0.01  {'auto_class_weights': 'Balanced', 'depth': 6,...
# 5                  0.10  {'auto_class_weights': 'Balanced', 'depth': 6,...
# 6                  0.01  {'auto_class_weights': 'Balanced', 'depth': 6,...
# 7                  0.10  {'auto_class_weights': 'Balanced', 'depth': 6,...
# 8                  0.01  {'auto_class_weights': 'Balanced', 'depth': 9,...
# 9                  0.10  {'auto_class_weights': 'Balanced', 'depth': 9,...
# 10                 0.01  {'auto_class_weights': 'Balanced', 'depth': 9,...
# 11                 0.10  {'auto_class_weights': 'Balanced', 'depth': 9,...
# 12                 0.01  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 13                 0.10  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 14                 0.01  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 15                 0.10  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 16                 0.01  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 17                 0.10  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 18                 0.01  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 19                 0.10  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 20                 0.01  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 21                 0.10  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 22                 0.01  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 23                 0.10  {'auto_class_weights': 'SqrtBalanced', 'depth'...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.843660           0.872347           0.878623
# 1            0.803500           0.826162           0.814921
# 2            0.839931           0.866036           0.861119
# 3            0.762478           0.786575           0.772453
# 4            0.778256           0.802352           0.757532
# 5            0.733792           0.775100           0.691535
# 6            0.769076           0.792025           0.743185
# 7            0.708835           0.739816           0.684648
# 8            0.798623           0.806081           0.764706
# 9            0.736948           0.740103           0.712769
# 10           0.774527           0.794607           0.749211
# 11           0.712278           0.723178           0.688953
# 12           0.855422           0.869191           0.859684
# 13           0.729203           0.738956           0.715925
# 14           0.852266           0.862020           0.851363
# 15           0.705393           0.721170           0.704735
# 16           0.748422           0.755881           0.731994
# 17           0.695927           0.711991           0.693544
# 18           0.715720           0.738095           0.712482
# 19           0.684165           0.704532           0.688953
# 20           0.718589           0.729489           0.718795
# 21           0.682157           0.698221           0.672597
# 22           0.691910           0.701377           0.687518
# 23           0.671830           0.694779           0.660545
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0            0.854232           0.547776         0.799328        0.126394
# 1            0.834433           0.593687         0.774541        0.091026
# 2            0.852511           0.581349         0.800189        0.109778
# 3            0.786514           0.600000         0.741604        0.071384
# 4            0.791679           0.545481         0.735060        0.095964
# 5            0.769871           0.593400         0.712740        0.066765
# 6            0.781923           0.563845         0.730011        0.084677
# 7            0.738594           0.595696         0.693518        0.053024
# 8            0.785653           0.571306         0.745274        0.088110
# 9            0.752941           0.595122         0.707577        0.057709
# 10           0.772740           0.572740         0.732765        0.081296
# 11           0.738881           0.601148         0.692887        0.048663
# 12           0.857963           0.706456         0.829743        0.061819
# 13           0.754089           0.605165         0.708668        0.053231
# 14           0.851076           0.624677         0.808280        0.091892
# 15           0.737733           0.605452         0.694897        0.046331
# 16           0.758680           0.599426         0.718881        0.060443
# 17           0.740603           0.601722         0.688757        0.046642
# 18           0.742324           0.596270         0.700978        0.053667
# 19           0.737733           0.604017         0.683880        0.044115
# 20           0.744907           0.598852         0.702126        0.052523
# 21           0.715925           0.607174         0.675215        0.037071
# 22           0.722812           0.597704         0.680264        0.043036
# 23           0.719082           0.609182         0.671084        0.036902
#
#     rank_test_score
# 0                 4
# 1                 5
# 2                 3
# 3                 7
# 4                 8
# 5                12
# 6                10
# 7                18
# 8                 6
# 9                14
# 10                9
# 11               19
# 12                1
# 13               13
# 14                2
# 15               17
# 16               11
# 17               20
# 18               16
# 19               21
# 20               15
# 21               23
# 22               22
# 23               24

# %%
pred = clf.best_estimator_.predict(test_df[['content']])

# %%
f1_score(test_df.topic.to_numpy(), pred, average='weighted')
# Out:
# 0.8552614328833373

# %% [markdown]
# **Вывод:** CatBoost плохо работает со встроенными параметрами обработки текста.

# %% [markdown]
# # CatBoostClassifier on clear text

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from pymystem3 import Mystem
from string import punctuation
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
mystem = Mystem() 
russian_stopwords = stopwords.words("russian")

# %%
def preprocess_text(text):
    tokens = mystem.lemmatize(text.lower())
    tokens = [token for token in tokens if token not in russian_stopwords\
              and token != " " \
              and token.strip() not in punctuation]
    
    text = " ".join(tokens)
    
    return text

# %%
train_df.content = train_df.content.apply(preprocess_text)
test_df.content = test_df.content.apply(preprocess_text)

# %%
param_grid = {
    'iterations': [100, 200],
    'learning_rate': [0.01, 0.1],
    'depth': [3, 6, 9],
    'auto_class_weights': ['Balanced', 'SqrtBalanced']
}

scorer = make_scorer(f1_score, average='weighted')

# %%
base_params = {
    'random_state': 42,
    "verbose": False,
    'early_stopping_rounds': 5,
    #'use_best_model': True,
    "loss_function": "MultiClass",
    'text_features': ['content']
}
model = CatBoostClassifier(**base_params)

# %%
clf = GridSearchCV(model, param_grid)

# %%
clf.fit(train_df[['content']], train_df.topic.to_numpy())
# Out:
# GridSearchCV(estimator=<catboost.core.CatBoostClassifier object at 0x7f43c44b0a60>,
#              param_grid={'auto_class_weights': ['Balanced', 'SqrtBalanced'],
#                          'depth': [3, 6, 9], 'iterations': [100, 200],
#                          'learning_rate': [0.01, 0.1]})

# %%
pd.DataFrame(clf.cv_results_)#.dropna(subset=['split0_test_score'])
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        3.768715      0.055168         0.053888        0.004351
# 1        3.708021      0.011115         0.050073        0.003418
# 2        7.028702      0.214062         0.044430        0.003129
# 3        6.549841      0.051249         0.042555        0.003323
# 4       19.820013      0.122248         0.049499        0.003356
# 5       19.471139      0.156368         0.052660        0.003063
# 6       38.734633      0.224491         0.046289        0.003116
# 7       37.951181      0.332758         0.045783        0.003819
# 8       64.978013      0.652478         0.054627        0.002390
# 9       65.779137      0.302328         0.054401        0.003250
# 10     130.029082      0.507454         0.047636        0.002145
# 11     130.594028      0.758548         0.047798        0.002208
# 12       4.075105      0.571762         0.049126        0.002503
# 13       3.637808      0.034075         0.050627        0.002943
# 14       6.711668      0.030283         0.040348        0.002565
# 15       6.424502      0.059428         0.041242        0.001967
# 16      20.232127      0.106279         0.048606        0.002838
# 17      19.776636      0.072331         0.053170        0.006077
# 18      39.270550      0.275687         0.044186        0.001299
# 19      38.036995      0.477624         0.049589        0.005757
# 20      65.677199      0.546654         0.053787        0.003916
# 21      65.677381      0.675727         0.054410        0.004317
# 22     132.691779      0.129233         0.045538        0.002334
# 23     132.296933      0.690563         0.046225        0.001900
#
#    param_auto_class_weights  param_depth  param_iterations  \
# 0                  Balanced            3               100
# 1                  Balanced            3               100
# 2                  Balanced            3               200
# 3                  Balanced            3               200
# 4                  Balanced            6               100
# 5                  Balanced            6               100
# 6                  Balanced            6               200
# 7                  Balanced            6               200
# 8                  Balanced            9               100
# 9                  Balanced            9               100
# 10                 Balanced            9               200
# 11                 Balanced            9               200
# 12             SqrtBalanced            3               100
# 13             SqrtBalanced            3               100
# 14             SqrtBalanced            3               200
# 15             SqrtBalanced            3               200
# 16             SqrtBalanced            6               100
# 17             SqrtBalanced            6               100
# 18             SqrtBalanced            6               200
# 19             SqrtBalanced            6               200
# 20             SqrtBalanced            9               100
# 21             SqrtBalanced            9               100
# 22             SqrtBalanced            9               200
# 23             SqrtBalanced            9               200
#
#     param_learning_rate                                             params  \
# 0                  0.01  {'auto_class_weights': 'Balanced', 'depth': 3,...
# 1                  0.10  {'auto_class_weights': 'Balanced', 'depth': 3,...
# 2                  0.01  {'auto_class_weights': 'Balanced', 'depth': 3,...
# 3                  0.10  {'auto_class_weights': 'Balanced', 'depth': 3,...
# 4                  0.01  {'auto_class_weights': 'Balanced', 'depth': 6,...
# 5                  0.10  {'auto_class_weights': 'Balanced', 'depth': 6,...
# 6                  0.01  {'auto_class_weights': 'Balanced', 'depth': 6,...
# 7                  0.10  {'auto_class_weights': 'Balanced', 'depth': 6,...
# 8                  0.01  {'auto_class_weights': 'Balanced', 'depth': 9,...
# 9                  0.10  {'auto_class_weights': 'Balanced', 'depth': 9,...
# 10                 0.01  {'auto_class_weights': 'Balanced', 'depth': 9,...
# 11                 0.10  {'auto_class_weights': 'Balanced', 'depth': 9,...
# 12                 0.01  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 13                 0.10  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 14                 0.01  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 15                 0.10  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 16                 0.01  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 17                 0.10  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 18                 0.01  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 19                 0.10  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 20                 0.01  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 21                 0.10  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 22                 0.01  {'auto_class_weights': 'SqrtBalanced', 'depth'...
# 23                 0.10  {'auto_class_weights': 'SqrtBalanced', 'depth'...
#
#     split0_test_score  split1_test_score  split2_test_score  \
# 0            0.863167           0.872060           0.886657
# 1            0.816982           0.825301           0.810617
# 2            0.860298           0.862593           0.879484
# 3            0.766208           0.798336           0.783357
# 4            0.803787           0.825014           0.811478
# 5            0.734079           0.780264           0.752654
# 6            0.777395           0.809524           0.790244
# 7            0.712565           0.763052           0.729412
# 8            0.789443           0.818130           0.790818
# 9            0.738669           0.771658           0.732855
# 10           0.765634           0.794320           0.772453
# 11           0.727768           0.750717           0.717647
# 12           0.882100           0.895009           0.879484
# 13           0.778543           0.780551           0.761836
# 14           0.881526           0.890419           0.874319
# 15           0.744406           0.751291           0.741463
# 16           0.798049           0.799197           0.784505
# 17           0.732932           0.771084           0.730846
# 18           0.769076           0.780551           0.766141
# 19           0.729203           0.755020           0.720803
# 20           0.777108           0.780551           0.766428
# 21           0.676994           0.733505           0.703300
# 22           0.723178           0.757889           0.732855
# 23           0.677854           0.734940           0.705595
#
#     split3_test_score  split4_test_score  mean_test_score  std_test_score  \
# 0            0.887518           0.664562         0.834793        0.085606
# 1            0.839885           0.640172         0.786592        0.073862
# 2            0.874605           0.670301         0.829456        0.079901
# 3            0.810043           0.632999         0.758189        0.064298
# 4            0.832138           0.617217         0.777927        0.080967
# 5            0.794261           0.618077         0.735867        0.062515
# 6            0.820373           0.618077         0.763123        0.074038
# 7            0.782496           0.626112         0.722727        0.054187
# 8            0.812339           0.627834         0.767713        0.070860
# 9            0.794835           0.622095         0.732022        0.059406
# 10           0.802869           0.621234         0.751302        0.066453
# 11           0.780775           0.629842         0.721350        0.050641
# 12           0.877475           0.739742         0.854762        0.057834
# 13           0.803730           0.634433         0.751819        0.060190
# 14           0.875753           0.711334         0.846670        0.067904
# 15           0.789670           0.638451         0.733056        0.050373
# 16           0.810617           0.648207         0.768115        0.060523
# 17           0.773888           0.626973         0.727145        0.053286
# 18           0.791392           0.636729         0.748778        0.056734
# 19           0.767575           0.630129         0.720546        0.048271
# 20           0.791392           0.646485         0.752393        0.053550
# 21           0.756671           0.622669         0.698628        0.046573
# 22           0.770445           0.628981         0.722670        0.049808
# 23           0.754376           0.623529         0.699259        0.045922
#
#     rank_test_score
# 0                 3
# 1                 5
# 2                 4
# 3                10
# 4                 6
# 5                15
# 6                 9
# 7                19
# 8                 8
# 9                17
# 10               13
# 11               21
# 12                1
# 13               12
# 14                2
# 15               16
# 16                7
# 17               18
# 18               14
# 19               22
# 20               11
# 21               24
# 22               20
# 23               23

# %%
pred = clf.best_estimator_.predict(test_df[['content']])

# %%
f1_score(test_df.topic.to_numpy(), pred, average='weighted')
# Out:
# 0.8679819666887993
